# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.tracers import ConsoleCallbackHandler

llm=ChatOpenAI(model="gpt-4o-mini",temperature=0.2)
prompt=ChatPromptTemplate.from_messages([
    ("system","Bạn là một phóng viên giỏi với khả năng tóm tắt các báo kinh tế và đầu tư"),
    ("human","Hãy tóm tắt nội dung bài báo sau không quá 200 từ, nội dung trả về bằng markdown, có các từ khóa quan trọng trong bài báo: {content}")
])
chain=prompt | llm | StrOutputParser()
result= chain.invoke(
    {'content':'''Cơ hội giảm thuế sâu cho dệt may, thủy sản, nông sản

Ngày 26/10, Việt Nam và Mỹ đã đồng ý công bố Tuyên bố chung về Khuôn khổ Hiệp định Thương mại đối ứng, công bằng và cân bằng. Nhiều thông tin tích cực trong tuyên bố mở ra kỳ vọng mới cho các ngành hàng xuất khẩu chủ lực của Việt Nam.

Trong thời gian tới, hai bên sẽ tiếp tục thảo luận và triển khai các công việc hướng đến việc hoàn tất Hiệp định Thương mại đối ứng, công bằng và cân bằng, trên nguyên tắc cởi mở, xây dựng, bình đẳng, tôn trọng độc lập, tự chủ, thể chế chính trị, cùng có lợi và cân nhắc đến trình độ phát triển của mỗi bên.

Ngành xuất khẩu nào sẽ được hưởng lợi và có khả năng giảm thuế về 0%?

Trao đổi với Báo Đầu tư Chứng khoán, ông Nguyễn Thế Minh, Giám đốc Nghiên cứu và Phát triển khách hàng cá nhân, Công ty Chứng khoán Yuanta Việt Nam cho rằng, trong giai đoạn tạm hoãn áp thuế đối ứng trước đó, Mỹ đã thể hiện rõ chủ trương áp thuế cao với các mặt hàng công nghệ và nhóm hàng Mỹ có khả năng tự sản xuất. Ngược lại, những mặt hàng tiêu dùng mà Mỹ phụ thuộc nhập khẩu sẽ được xem xét lại mức thuế nhập khẩu.

“Các nhóm hàng nổi bật như dệt may, thực phẩm tiêu dùng, thủy sản, đồ gỗ mỹ nghệ… là những sản phẩm Mỹ chưa tự chủ sản xuất. Nếu áp thuế cao, người tiêu dùng Mỹ sẽ chịu tác động trực tiếp khi giá hàng hóa tăng, kéo theo áp lực lạm phát”, ông Minh nhận định.

Ông Minh cho biết thêm, khi áp thuế cao với nhiều mặt hàng, tăng trưởng kinh tế Mỹ chậm lại, đầu tư sụt giảm, lạm phát tăng do chi phí đẩy. Trong bối cảnh đó, Cục Dự trữ Liên bang Mỹ (Fed) có xu hướng giảm tốc trong các biện pháp điều chỉnh lãi suất.

“Mỹ cần xem xét lại chính sách thuế, phân hóa theo từng nhóm hàng để phù hợp hơn. Với các sản phẩm mà Mỹ phụ thuộc nhập khẩu từ Việt Nam như dệt may, thủy sản, đồ gỗ…, cơ hội giảm thuế xuống 0% là khả thi. Khi đó, người tiêu dùng Mỹ sẽ là đối tượng hưởng lợi đầu tiên”, ông Minh nhận định.

Trong lĩnh vực dệt may, giới phân tích cho rằng, Việt Nam đang sở hữu lợi thế cạnh tranh lớn, là quốc gia xuất khẩu dệt may lớn thứ hai thế giới và đứng thứ ba về xuất khẩu vào thị trường Mỹ. Mỹ hiện không sản xuất dệt may trong nước, nhiều thương hiệu dệt may lớn đang đặt nhà máy tại Việt Nam. Do đó, nếu quá trình đàm phán thuế đối ứng đạt tiến triển, khả năng giảm sâu hơn nữa mức thuế nhập khẩu - thậm chí về 0% - là hoàn toàn có cơ sở.

Các mặt hàng nông sản, thủy sản của Việt Nam cũng đứng trước cơ hội giảm thuế, qua đó nâng cao năng lực cạnh tranh với các quốc gia trong khu vực.

Theo Công ty Chứng khoán Sài Gòn - Hà Nội (SHS), lo ngại về chính sách thuế quan dưới thời Tổng thống Donald Trump có thể gây tổn hại cho kinh tế Việt Nam đang dần biến mất. Dù phải đối mặt với mức thuế đối ứng 20%, hoạt động sản xuất và đầu tư vào Việt Nam vẫn duy trì đà tăng trưởng mạnh mẽ.

Kết quả kinh doanh khởi sắc củng cố niềm tin thị trường

Chính sách thuế thuận lợi sẽ mở ra cơ hội tăng trưởng mới cho doanh nghiệp xuất khẩu Việt Nam và nhóm cổ phiếu liên quan.

Hoạt động kinh doanh của nhóm doanh nghiệp xuất khẩu từ đầu năm đến nay ghi nhận nhiều điểm sáng, với kết quả 9 tháng tích cực - yếu tố hỗ trợ đáng kể cho đà tăng giá cổ phiếu nhóm này.

Lũy kế 9 tháng đầu năm 2025, Công ty cổ phần Đầu tư Thương mại TNG (mã TNG) đạt 5.711 tỷ đồng doanh thu, tăng 14,6%; lợi nhuận sau thuế đạt 280 tỷ đồng, tăng 16,6% so với cùng kỳ. Năm 2025, TNG đặt mục tiêu đạt doanh thu 8.100 tỷ đồng và lợi nhuận sau thuế 340 tỷ đồng. Với kết quả hiện tại, doanh nghiệp đã hoàn thành 70,5% kế hoạch doanh thu và 82,3% kế hoạch lợi nhuận. Đại diện TNG cho biết, Công ty đang bám sát mục tiêu với triển vọng kinh doanh tích cực.

Một doanh nghiệp khác tăng trưởng mạnh là Tổng công ty May 10 (mã M10). Quý III/2025, doanh nghiệp ghi nhận lợi nhuận sau thuế 48,5 tỷ đồng, tăng 52% so với cùng kỳ - mức lợi nhuận theo quý cao nhất kể từ năm 2023. Lũy kế 9 tháng, doanh thu đạt 3.340 tỷ đồng (tăng 10%), lợi nhuận sau thuế đạt 77,9 tỷ đồng (tăng 59%).

Tại Công ty cổ phần Dệt may - Đầu tư - Thương mại Thành Công (mã TCM), doanh thu 9 tháng đạt 2.727 tỷ đồng, hoàn thành 60% kế hoạch năm; lợi nhuận sau thuế đạt 218 tỷ đồng, hoàn thành 78% kế hoạch năm. TCM cho biết, sẽ tăng tốc trong quý IV - giai đoạn có nhiều lợi thế về đơn hàng và nhu cầu tăng cao tại các thị trường lớn như Mỹ, EU…

Trong lĩnh vực xuất khẩu thủy sản, Công ty cổ phần Vĩnh Hoàn (mã chứng khoán VHC), Công ty cổ phần Thực phẩm Sao Ta (mã chứng khoán FMC), Công ty cổ phần Nam Việt (mã chứng khoán ANV)… đều ghi nhận kết quả kinh doanh sáng.

Trong lĩnh vực thủy sản, các doanh nghiệp như Vĩnh Hoàn (mã VHC), Thực phẩm Sao Ta (mã FMC), Nam Việt (mã ANV) đều ghi nhận kết quả tích cực. Cụ thể, Vĩnh Hoàn báo lợi nhuận sau thuế hợp nhất quý III đạt 455 tỷ đồng, tăng 35% so với cùng kỳ; lũy kế 9 tháng đạt 1.206 tỷ đồng, tăng 38,6%. Thực phẩm Sao Ta ghi nhận lợi nhuận quý III đạt 111,8 tỷ đồng (tăng 18%), lũy kế 9 tháng đạt 251,2 tỷ đồng (tăng 6,7%). Nam Việt gây chú ý với lợi nhuận sau thuế quý III đạt 283 tỷ đồng, tăng tới 917% so với cùng kỳ; lũy kế 9 tháng đạt gần 748 tỷ đồng - gấp 17 lần.

Đối với nhóm xuất khẩu đồ gỗ, Công ty cổ phần Phú Tài (mã PTB) đã hoàn thành kế hoạch lợi nhuận năm 2025 chỉ sau 9 tháng, với lợi nhuận trước thuế đạt 35 tỷ đồng. Trong quý IV, Công ty đặt mục tiêu thêm 5 tỷ đồng lợi nhuận (nếu đạt sẽ vượt 14% kế hoạch năm).

Trên thị trường chứng khoán, nhóm cổ phiếu xuất khẩu đã phản ứng tích cực trước thông tin về thuế quan, nhiều mã như TNG, M10, MSH, PTB… bật tăng mạnh mẽ.

Ông Nguyễn Thế Minh cho rằng, khả năng đạt được kịch bản thuế quan thuận lợi là cao khi hai bên bước vào giai đoạn đàm phán, thỏa thuận khung. Chính sách tốt sẽ mở ra cơ hội tăng trưởng mới cho doanh nghiệp xuất khẩu Việt Nam và nhóm cổ phiếu liên quan. Một số hàng hóa có thể được áp mức thuế thấp hơn 20% hoặc giảm về 0%.

Theo SHS, mục tiêu đầu tư nên hướng tới các mã có nền tảng cơ bản tốt, vị thế đầu ngành trong các lĩnh vực chiến lược, tăng trưởng vượt trội và giao dịch quanh vùng giá hợp lý.'''},
    config={"callbacks":[ConsoleCallbackHandler]}
)

# %%
llm
# Out:
# ChatOpenAI(client=<openai.resources.chat.completions.completions.Completions object at 0x00000274230DBDD0>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x000002742368CC50>, root_client=<openai.OpenAI object at 0x00000274217B09E0>, root_async_client=<openai.AsyncOpenAI object at 0x00000274231BA9F0>, model_name='gpt-4o-mini', temperature=0.2, model_kwargs={}, openai_api_key=SecretStr('**********'), stream_usage=True)

# %%
from IPython.display import Markdown, display

clean_result = result.strip("```").replace("markdown\n", "")
display(Markdown(clean_result))
# Out:
# ### Tóm tắt bài báo: Cơ hội giảm thuế sâu cho dệt may, thủy sản, nông sản
#
# Ngày 26/10, Việt Nam và Mỹ công bố Tuyên bố chung về Hiệp định Thương mại đối ứng, mở ra cơ hội giảm thuế cho các ngành xuất khẩu chủ lực như **dệt may**, **thủy sản**, và **nông sản**. Ông Nguyễn Thế Minh từ Công ty Chứng khoán Yuanta cho rằng, Mỹ có thể giảm thuế xuống 0% cho các mặt hàng mà họ phụ thuộc nhập khẩu từ Việt Nam, nhằm giảm áp lực lạm phát.
#
# Việt Nam hiện là quốc gia xuất khẩu dệt may lớn thứ hai thế giới, với nhiều thương hiệu lớn đặt nhà máy tại đây. Các doanh nghiệp như **TNG**, **M10**, và **TCM** ghi nhận kết quả kinh doanh tích cực trong 9 tháng đầu năm 2025, với doanh thu và lợi nhuận tăng trưởng mạnh.
#
# Trong lĩnh vực thủy sản, **Vĩnh Hoàn**, **Sao Ta**, và **Nam Việt** cũng có kết quả khả quan. Nhóm cổ phiếu xuất khẩu đã phản ứng tích cực trước thông tin về thuế quan, mở ra cơ hội tăng trưởng mới cho doanh nghiệp và nhà đầu tư.
#
# ...

# %%
from langchain_openai import ChatOpenAI 
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import PydanticOutputParser
from pydantic import Field,BaseModel
class Summary(BaseModel):
    title:str=Field(...,description='Tiêu đề tóm tắt')
    bullet:list[str]=Field(...,description='Danh sách các ý chính')
    sentiment:int=Field(...,description='Phân tích cảm xúc bài viết: -1 là tiêu cực, 0 là trung lập, 1 là tích cực')
llm=ChatOpenAI(model='gpt-4o-mini',temperature=0.2)

parse=PydanticOutputParser(pydantic_object=Summary)
format_intructions=parse.get_format_instructions()
prompt=ChatPromptTemplate.from_messages([
    ("system","Bạn là chuyên gia tổng hợp tin tức đầu tư và chứng khoán"),
    ("human","Hãy viết tóm tắt bài báo nội dung sau:{content}.\n{format_intructions}")
]).partial(format_intructions=format_intructions)
chain=(prompt | llm | parse).invoke(
        {'content':'''Cơ hội giảm thuế sâu cho dệt may, thủy sản, nông sản

Ngày 26/10, Việt Nam và Mỹ đã đồng ý công bố Tuyên bố chung về Khuôn khổ Hiệp định Thương mại đối ứng, công bằng và cân bằng. Nhiều thông tin tích cực trong tuyên bố mở ra kỳ vọng mới cho các ngành hàng xuất khẩu chủ lực của Việt Nam.

Trong thời gian tới, hai bên sẽ tiếp tục thảo luận và triển khai các công việc hướng đến việc hoàn tất Hiệp định Thương mại đối ứng, công bằng và cân bằng, trên nguyên tắc cởi mở, xây dựng, bình đẳng, tôn trọng độc lập, tự chủ, thể chế chính trị, cùng có lợi và cân nhắc đến trình độ phát triển của mỗi bên.

Ngành xuất khẩu nào sẽ được hưởng lợi và có khả năng giảm thuế về 0%?

Trao đổi với Báo Đầu tư Chứng khoán, ông Nguyễn Thế Minh, Giám đốc Nghiên cứu và Phát triển khách hàng cá nhân, Công ty Chứng khoán Yuanta Việt Nam cho rằng, trong giai đoạn tạm hoãn áp thuế đối ứng trước đó, Mỹ đã thể hiện rõ chủ trương áp thuế cao với các mặt hàng công nghệ và nhóm hàng Mỹ có khả năng tự sản xuất. Ngược lại, những mặt hàng tiêu dùng mà Mỹ phụ thuộc nhập khẩu sẽ được xem xét lại mức thuế nhập khẩu.

“Các nhóm hàng nổi bật như dệt may, thực phẩm tiêu dùng, thủy sản, đồ gỗ mỹ nghệ… là những sản phẩm Mỹ chưa tự chủ sản xuất. Nếu áp thuế cao, người tiêu dùng Mỹ sẽ chịu tác động trực tiếp khi giá hàng hóa tăng, kéo theo áp lực lạm phát”, ông Minh nhận định.

Ông Minh cho biết thêm, khi áp thuế cao với nhiều mặt hàng, tăng trưởng kinh tế Mỹ chậm lại, đầu tư sụt giảm, lạm phát tăng do chi phí đẩy. Trong bối cảnh đó, Cục Dự trữ Liên bang Mỹ (Fed) có xu hướng giảm tốc trong các biện pháp điều chỉnh lãi suất.

“Mỹ cần xem xét lại chính sách thuế, phân hóa theo từng nhóm hàng để phù hợp hơn. Với các sản phẩm mà Mỹ phụ thuộc nhập khẩu từ Việt Nam như dệt may, thủy sản, đồ gỗ…, cơ hội giảm thuế xuống 0% là khả thi. Khi đó, người tiêu dùng Mỹ sẽ là đối tượng hưởng lợi đầu tiên”, ông Minh nhận định.

Trong lĩnh vực dệt may, giới phân tích cho rằng, Việt Nam đang sở hữu lợi thế cạnh tranh lớn, là quốc gia xuất khẩu dệt may lớn thứ hai thế giới và đứng thứ ba về xuất khẩu vào thị trường Mỹ. Mỹ hiện không sản xuất dệt may trong nước, nhiều thương hiệu dệt may lớn đang đặt nhà máy tại Việt Nam. Do đó, nếu quá trình đàm phán thuế đối ứng đạt tiến triển, khả năng giảm sâu hơn nữa mức thuế nhập khẩu - thậm chí về 0% - là hoàn toàn có cơ sở.

Các mặt hàng nông sản, thủy sản của Việt Nam cũng đứng trước cơ hội giảm thuế, qua đó nâng cao năng lực cạnh tranh với các quốc gia trong khu vực.

Theo Công ty Chứng khoán Sài Gòn - Hà Nội (SHS), lo ngại về chính sách thuế quan dưới thời Tổng thống Donald Trump có thể gây tổn hại cho kinh tế Việt Nam đang dần biến mất. Dù phải đối mặt với mức thuế đối ứng 20%, hoạt động sản xuất và đầu tư vào Việt Nam vẫn duy trì đà tăng trưởng mạnh mẽ.

Kết quả kinh doanh khởi sắc củng cố niềm tin thị trường

Chính sách thuế thuận lợi sẽ mở ra cơ hội tăng trưởng mới cho doanh nghiệp xuất khẩu Việt Nam và nhóm cổ phiếu liên quan.

Hoạt động kinh doanh của nhóm doanh nghiệp xuất khẩu từ đầu năm đến nay ghi nhận nhiều điểm sáng, với kết quả 9 tháng tích cực - yếu tố hỗ trợ đáng kể cho đà tăng giá cổ phiếu nhóm này.

Lũy kế 9 tháng đầu năm 2025, Công ty cổ phần Đầu tư Thương mại TNG (mã TNG) đạt 5.711 tỷ đồng doanh thu, tăng 14,6%; lợi nhuận sau thuế đạt 280 tỷ đồng, tăng 16,6% so với cùng kỳ. Năm 2025, TNG đặt mục tiêu đạt doanh thu 8.100 tỷ đồng và lợi nhuận sau thuế 340 tỷ đồng. Với kết quả hiện tại, doanh nghiệp đã hoàn thành 70,5% kế hoạch doanh thu và 82,3% kế hoạch lợi nhuận. Đại diện TNG cho biết, Công ty đang bám sát mục tiêu với triển vọng kinh doanh tích cực.

Một doanh nghiệp khác tăng trưởng mạnh là Tổng công ty May 10 (mã M10). Quý III/2025, doanh nghiệp ghi nhận lợi nhuận sau thuế 48,5 tỷ đồng, tăng 52% so với cùng kỳ - mức lợi nhuận theo quý cao nhất kể từ năm 2023. Lũy kế 9 tháng, doanh thu đạt 3.340 tỷ đồng (tăng 10%), lợi nhuận sau thuế đạt 77,9 tỷ đồng (tăng 59%).

Tại Công ty cổ phần Dệt may - Đầu tư - Thương mại Thành Công (mã TCM), doanh thu 9 tháng đạt 2.727 tỷ đồng, hoàn thành 60% kế hoạch năm; lợi nhuận sau thuế đạt 218 tỷ đồng, hoàn thành 78% kế hoạch năm. TCM cho biết, sẽ tăng tốc trong quý IV - giai đoạn có nhiều lợi thế về đơn hàng và nhu cầu tăng cao tại các thị trường lớn như Mỹ, EU…

Trong lĩnh vực xuất khẩu thủy sản, Công ty cổ phần Vĩnh Hoàn (mã chứng khoán VHC), Công ty cổ phần Thực phẩm Sao Ta (mã chứng khoán FMC), Công ty cổ phần Nam Việt (mã chứng khoán ANV)… đều ghi nhận kết quả kinh doanh sáng.

Trong lĩnh vực thủy sản, các doanh nghiệp như Vĩnh Hoàn (mã VHC), Thực phẩm Sao Ta (mã FMC), Nam Việt (mã ANV) đều ghi nhận kết quả tích cực. Cụ thể, Vĩnh Hoàn báo lợi nhuận sau thuế hợp nhất quý III đạt 455 tỷ đồng, tăng 35% so với cùng kỳ; lũy kế 9 tháng đạt 1.206 tỷ đồng, tăng 38,6%. Thực phẩm Sao Ta ghi nhận lợi nhuận quý III đạt 111,8 tỷ đồng (tăng 18%), lũy kế 9 tháng đạt 251,2 tỷ đồng (tăng 6,7%). Nam Việt gây chú ý với lợi nhuận sau thuế quý III đạt 283 tỷ đồng, tăng tới 917% so với cùng kỳ; lũy kế 9 tháng đạt gần 748 tỷ đồng - gấp 17 lần.

Đối với nhóm xuất khẩu đồ gỗ, Công ty cổ phần Phú Tài (mã PTB) đã hoàn thành kế hoạch lợi nhuận năm 2025 chỉ sau 9 tháng, với lợi nhuận trước thuế đạt 35 tỷ đồng. Trong quý IV, Công ty đặt mục tiêu thêm 5 tỷ đồng lợi nhuận (nếu đạt sẽ vượt 14% kế hoạch năm).

Trên thị trường chứng khoán, nhóm cổ phiếu xuất khẩu đã phản ứng tích cực trước thông tin về thuế quan, nhiều mã như TNG, M10, MSH, PTB… bật tăng mạnh mẽ.

Ông Nguyễn Thế Minh cho rằng, khả năng đạt được kịch bản thuế quan thuận lợi là cao khi hai bên bước vào giai đoạn đàm phán, thỏa thuận khung. Chính sách tốt sẽ mở ra cơ hội tăng trưởng mới cho doanh nghiệp xuất khẩu Việt Nam và nhóm cổ phiếu liên quan. Một số hàng hóa có thể được áp mức thuế thấp hơn 20% hoặc giảm về 0%.

Theo SHS, mục tiêu đầu tư nên hướng tới các mã có nền tảng cơ bản tốt, vị thế đầu ngành trong các lĩnh vực chiến lược, tăng trưởng vượt trội và giao dịch quanh vùng giá hợp lý.'''}


)

# %%
from langchain_core.prompts import  ChatPromptTemplate
from langchain_core.output_parsers import PydanticOutputParser
from langchain_openai import ChatOpenAI
from pydantic import Field,BaseModel
class Summary(BaseModel):
    title:str=Field(...,description="title tóm tắt")
    summary:str=Field(...,description='Tóm tắt ý chính tối đa 5 gạch đầu dòng')
    sentiment:int=Field(...,description='Phân loại cảm xúc bài viết: -1 | 0 | 1 trong đó: -1 là tiêu cực, 0 là trung lập, 1 là tích cực')
llm=ChatOpenAI(model='gpt-4o-mini',temperature=0.2)
parse=PydanticOutputParser(pydantic_object=Summary)
format_instructions=parse.get_format_instructions()
prompt=ChatPromptTemplate.from_messages([
    ('system',' Bạn là chuyên gia phân tích và tổng hợp tin tức đầu tư'),
    ('human','Tóm tắt nội dung: {content} \n {format_instructions}')
]).partial(format_instructions=format_instructions)
chain= (prompt | llm | parse).invoke({'content':'''Các nhận định trên được đưa ra tại cuộc thảo luận về “Chiến lược đầu tư 2026: Ngành dẫn dắt, cổ phiếu trọng điểm và hành vi dòng tiền mới” trong Diễn đàn Đầu tư Việt Nam 2026 do VietnamBiz và Việt Nam Mới phối hợp tổ chức tại TP.HCM vừa qua.

Kịch bản nào cho thị trường năm 2026

Ông Huỳnh Minh Tuấn, Nhà sáng lập Công ty cổ phần đầu tư và quản lý Tài sản FIDT, Phó chủ tịch Chứng khoán APG cho biết, ban tổ chức thực hiện khảo sát với kết quả 68% người được hỏi nhận định thị trường sẽ tăng và 21% nói sẽ đi ngang trong năm 2026.

Ông Đào Phúc Tường, Chuyên gia chứng khoán với biệt danh là “Guru đầu bạc” cho biết, ông thuộc nhóm 21%. Thị trường năm tới sẽ phần nào dựa vào diễn biến 2 tháng cuối năm nay. Tuy nhiên, năm nay thị trường đã tăng hơn 30% trên nền tảng lợi nhuận doanh nghiệp công bố với nhiều khoản bất thường, nếu kỳ vọng năm 2026 tiếp tục duy trì những khoản lợi nhuận lớn thì quá là lạc quan.

"Định giá các nhóm ngành đang ở mức trung bình so với trung bình 3 năm, không phải là đắt và không phải là rẻ. Quý IV/2025 sẽ có áp lực lớn về tăng trưởng lợi nhuận vì so sánh với nền cùng kỳ ở mức cao, sau khi 3 quý đầu tăng trưởng trên nền so sánh thấp", ông Tường nhận định.
Trong khi đó, ông Quản Trọng Thành, Giám đốc khối Phân tích chứng khoán Maybank Securities Vietnam nhìn nhận thị trường tích cực. Ông Thành dẫn chứng về Kuwait và Saudi Arabia sau thời điểm nâng hạng thường có cú giảm mạnh vì đã tăng mạnh trước đó nên nhà đầu tư chốt lời, giống thị trường chứng khoán Việt Nam hiện tại. Khi thị trường điều chỉnh sẽ mở ra cơ hội mới cho nhà đầu tư nước ngoài mua vào.

“Tôi đã trả lời rất nhiều nhà đầu tư nước ngoài những câu hỏi cơ bản về thị trường Việt Nam gần đây. Nếu nhìn lãi suất tiền gửi bình quân 12 tháng là dưới 6%, ngay cả khi về 6%, định giá thị trường P/E 14 là hợp lý thì chúng tôi đánh giá thị trường có thể đạt 1.900 điểm. Với ngành ngân hàng, định giá của nhóm ngành này trong một năm chỉ còn 1,24 lần P/B, nếu nhìn dài hạn thì đây là mức định giá tốt. Đặc biệt, nếu nắm giữ từ năm 2020 - 2024 thì mức sinh lời của các cổ phiếu ngân hàng rất cao, dù trong giai đoạn này có nhiều nhiều biến cố xảy ra. Với thanh khoản cao, cổ phiếu ngân hàng thuộc top giao dịch sôi động của thị trường, nhà đầu tư có thể dễ dàng mua bán và chuyển đổi thành tiền mặt khi cần”, ông Thành phân tích.

Ông Lê Đức Khánh Giám đốc phân tích VPS nhận định, thị trường vẫn đang ở trong một uptrend mới, triển vọng năm tới rất lạc quan, chỉ số VN-Index sẽ đạt được các mốc 1.800 - 2.000. Nhóm tài chính có tiềm năng bao gồm cả ngân hàng, chứng khoán, bảo hiểm hay nhóm ngành dầu khí cảng biển. Nhóm chứng khoán hoạt động như mô hình ngân hàng đầu tư có rất nhiều dư địa để tăng trưởng lợi nhuận.

Cùng quan điểm với ông Thành, bà Chu Thị Kim Hương, Giám đốc Phòng khách hàng Định chế ACBS cho rằng, việc bán trên thị trường chỉ là chốt lãi ngắn hạn. Về dài hạn, với các đề án nâng hạng, mục tiêu tăng trưởng GDP, chính sách tiền tệ thúc đẩy tăng trưởng thì năm 2026 vẫn là cơ hội để mọi người làm giàu từ thị trường chứng khoán.

Về định giá thị trường, ông Tuấn cho rằng, P/E hiện là 14 và chiết khấu về cuối năm khoảng 13 là tương đối hấp dẫn trong bối cảnh kỳ vọng kinh tế tăng trưởng. Nếu P/E thị trường về khoảng 11 lần vào 2026 thì định giá thị trường là rẻ, nhưng vẫn phải dựa trên đánh giá các nhóm ngành.

Không chắc chắn về triển vọng lợi nhuận bất động sản, chuyên gia "gợi ý" 3 chữ cái

Dù giữ quan điểm trung lập về thị trường chung nhưng ông Tường cho rằng, thị trường sẽ phân hóa theo nhóm ngành. Nhóm vật liệu xây dựng như cát - đá - sỏi vẫn còn tăng trưởng 15 - 20% nhờ xây dựng phục hồi, trong khi P/E chỉ đạt 8 - 10 lần, trong đó, doanh nghiệp nào còn trữ lượng thì sẽ được hưởng lợi. Trong khi đó, các doanh nghiệp dầu khí đang giao dịch dưới định giá tiền mặt.

“Một số trụ cột của VN-Index khó tăng trưởng lợi nhuận, vì vậy, tôi cho rằng chỉ số chung sẽ khó tăng. Tuy nhiên, trên thị trường vẫn sẽ có những công ty tăng trưởng rất tốt”, ông Tường nói.

Về bất động sản, ngành đang được nhiều nhà đầu tư quan tâm, ông Thành thẳng thắn: “Ngành bất động sản vẫn chưa cho thấy sự yên tâm. Phần cung khá tốt khi các doanh nghiệp triển khai dự án bất động sản, nhưng bán ra như thế nào khi nguồn cung nhiều mà giá cao quá. Nếu tầm nhìn trong vài tháng tới thì vẫn ổn, nhưng nếu xa hơn thì không chắc chắn, tuy nhiên, ngành này sẽ có sự phân hóa”.

“Nhóm bất động sản có nhiều sóng cho mua bán kiếm tiền, nhất là doanh nghiệp từ dưới bùn đi lên”, ông Tường lưu ý thêm và đưa ra nhận định đối với cổ phiếu đầu ngành thép - HPG.

Theo ông Tường, HPG cũng là lựa chọn tại thời điểm này vì là cổ phiếu đầu ngành được định giá hợp lý và hưởng lợi khi Trung Quốc tăng tiêu dùng, giảm sản xuất. HPG định giá P/E 14-15 lần, có thể chờ nhà máy mới đi vào hoạt động tăng công suất. Nếu cộng thêm hưởng lợi từ Trung Quốc giảm sản xuất, thì HPG sẽ có tăng trưởng cao.

Nếu nhìn về năm 2026, ông Thành chọn cổ phiếu ngân hàng tư nhân HDB có tỷ suất sinh lợi ROE cao, hệ sinh thái cần vốn và phát hành cho nhà đầu tư nước ngoài. Cổ phiếu ngân hàng thứ 2 là TCB gắn với tăng trưởng tín dụng, quý IV tăng trưởng mạnh, thị trường sẽ đánh giá lại, chưa kể nếu TCX vào VN30 sẽ tạo hiệu ứng.

Trong khi đó, ông Khánh lưu ý PVD giá đang thấp hơn giá trị sổ sách, các giàn khoan đều có công việc hay Cảng Hải An bắt đầu ghi nhận lợi nhuận kỷ lục. “Tôi thích doanh nghiệp có kết quả kinh doanh vượt trội, bởi sẽ nhận được dòng tiền quan tâm trở lại và độ tăng giá cổ phiếu vẫn còn”, ông Khánh nói.

Làn sóng IPO, tham gia hay đứng nhìn?

Nói về làn sóng IPO, ông Tường khẳng định: “Cá nhân tôi sẽ không tham gia IPO doanh nghiệp tư nhân, ít nhất cho đến khi cổ phiếu này niêm yết mới xem xét tiếp. Giai đoạn 2016 -2017, khi làm cho quỹ, đứng trước làn sóng IPO, chúng tôi chỉ tham gia IPO ACV là doanh nghiệp nhà nước. Lý do là vì các doanh nghiệp sẽ xây dựng kế hoạch tăng trưởng màu hồng và chưa biết có thực hiện được không”.

Tuy nhiên, ông Tường cũng cho rằng, IPO về dài hạn rất tốt cho thị trường vì thêm hàng hóa mới. Tới đây, thị trường sẽ có nhiều thương vụ IPO và doanh nghiệp phải cạnh tranh huy động vốn, nhà đầu tư cũng sẽ có nhiều lựa chọn. Nhà đầu tư có thể quan sát và chờ doanh nghiệp có mức giá IPO hợp lý để tham gia dựa trên các tiêu chí mục tiêu tăng trưởng, định giá và lượng cổ phiếu tự do giao dịch.

Theo bà Hương, các định chế quan tâm hỏi các vụ IPO và hơn 50% định chế phải tham gia IPO vì họ phải theo các chỉ số lớn. Nhà đầu tư quan tâm đến thị trường vào sau sẽ phải tham gia IPO và ETF vì gắn hiệu quả đầu tư theo thị trường.

Về vấn đề này, ông Thành cho rằng, doanh nghiệp không nên chỉ huy động vốn trong nước mà còn huy động vốn nước ngoài để IPO thành công.

“IPO không tốt, không xấu, mà vấn đề là chúng ta làm bài tập nhiều. Năm sau nhiều doanh nghiệp đa dạng sẽ IPO, tôi đánh giá cao làn sóng IPO này sẽ hút dòng tiền vào chứng khoán”, ông Tuấn nhấn mạnh.

Bà Hương cũng cho rằng, IPO với chiến lược và độ phủ truyền thông rất quan trọng. Nếu doanh nghiệp như Đất Việt lên sàn thì sẽ thu hút thêm một lượng fan của Anh Trai hay Em Xinh vào thị trường để ủng hộ cho các Idol của mình...

Làn sóng IPO sẽ tăng thêm hàng hóa cho thị trường, đem lại nhiều sự lựa chọn và sôi động dòng vốn đầu tư.'''})

# %%
print(chain.summary)
# Out:
# 1. 68% người tham gia khảo sát dự đoán thị trường sẽ tăng trong năm 2026. 2. Các chuyên gia nhận định thị trường sẽ phân hóa theo nhóm ngành, với nhóm ngân hàng và chứng khoán có tiềm năng tăng trưởng. 3. Ngành bất động sản vẫn chưa ổn định, cần theo dõi sự phân hóa. 4. Làn sóng IPO sẽ tăng cường sự lựa chọn cho nhà đầu tư và thu hút dòng tiền vào thị trường. 5. Định giá thị trường hiện tại được đánh giá là hợp lý với P/E khoảng 14.
